# %%
import pandas as pd

# %%
s1 = pd.Series(['a', 'b', 'c'])
s2 = pd.Series(['d', 'e', 'f', 'z'])

# %%
pd.concat([s1, s2])
# Out:
# 0    a
# 1    b
# 2    c
# 0    d
# 1    e
# 2    f
# 3    z
# dtype: object

# %%
pd.concat([s2,s1])
# Out:
# 0    d
# 1    e
# 2    f
# 3    z
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.concat([s2,s1], ignore_index=True)
# Out:
# 0    d
# 1    e
# 2    f
# 3    z
# 4    a
# 5    b
# 6    c
# dtype: object

# %%
nums = pd.Series([65,69,99,23,56,56,52])

# %%
pd.concat([s2,s1, nums], ignore_index=True)
# Out:
# 0      d
# 1      e
# 2      f
# 3      z
# 4      a
# 5      b
# 6      c
# 7     65
# 8     69
# 9     99
# 10    23
# 11    56
# 12    56
# 13    52
# dtype: object

# %%
nums2 = pd.Series([86, 45, 23, 78, 45, 23, 45])

# %%
pd.concat([nums, nums2], ignore_index=True)
# Out:
# 0     65
# 1     69
# 2     99
# 3     23
# 4     56
# 5     56
# 6     52
# 7     86
# 8     45
# 9     23
# 10    78
# 11    45
# 12    23
# 13    45
# dtype: int64

# %%
c1 = pd.Series(['red', 'orange', 'yellow'])
c2 = pd.Series(['green', 'blue', 'purple'])

# %%
pd.concat([c1, c2])
# Out:
# 0       red
# 1    orange
# 2    yellow
# 0     green
# 1      blue
# 2    purple
# dtype: object

# %%
pd.concat([c1, c2], axis=1)
# Out:
#         0       1
# 0     red   green
# 1  orange    blue
# 2  yellow  purple

# %%
fruits = pd.Series(['apple', 'banana', 'cherry'], index=['a', 'b', 'c'])
animals = pd.Series(['badger', 'cougar', 'anaconda'], index=['b', 'c', 'a'])

# %%
fruits
# Out:
# a     apple
# b    banana
# c    cherry
# dtype: object

# %%
animals
# Out:
# b      badger
# c      cougar
# a    anaconda
# dtype: object

# %%
pd.concat([fruits, animals])
# Out:
# a       apple
# b      banana
# c      cherry
# b      badger
# c      cougar
# a    anaconda
# dtype: object

# %%
pd.concat([fruits, animals], axis=1)
# Out:
#         0         1
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar

# %%
pd.concat([fruits, animals], axis=1, keys=['fruit', 'animal'])
# Out:
#     fruit    animal
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar

# %%
pd.concat([fruits, animals], axis=0, keys=['fruit', 'animal'])
# Out:
# fruit   a       apple
#         b      banana
#         c      cherry
# animal  b      badger
#         c      cougar
#         a    anaconda
# dtype: object

# %%
fruits = pd.Series(
    ['apple', 'banana', 'cherry', 'durian'],
    index=['a', 'b', 'c', 'd']
)
animals = pd.Series(
    ['badger', 'cougar', 'anaconda', 'elk', 'pika'],
    index=['b', 'c', 'a', 'e', 'p']
)

# %%
pd.concat([fruits, animals])
# Out:
# a       apple
# b      banana
# c      cherry
# d      durian
# b      badger
# c      cougar
# a    anaconda
# e         elk
# p        pika
# dtype: object

# %%
pd.concat([fruits, animals], ignore_index=True)
# Out:
# 0       apple
# 1      banana
# 2      cherry
# 3      durian
# 4      badger
# 5      cougar
# 6    anaconda
# 7         elk
# 8        pika
# dtype: object

# %%
pd.concat([fruits, animals], axis=1)
# Out:
#         0         1
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar
# d  durian       NaN
# e     NaN       elk
# p     NaN      pika

# %%
pd.concat([fruits, animals], axis=1, join='outer')
# Out:
#         0         1
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar
# d  durian       NaN
# e     NaN       elk
# p     NaN      pika

# %%
pd.concat([fruits, animals], axis=1, join='inner')
# Out:
#         0         1
# a   apple  anaconda
# b  banana    badger
# c  cherry    cougar

# %%
harvest_21 = pd.DataFrame(
    [['potatoes', 900], ['garlic', 1350], ['onions', 875]],
    columns=['crop', 'qty']
)

harvest_22 = pd.DataFrame(
    [['garlic', 1600], ['spinach', 560], ['turnips', 999], ['onions', 1000]],
    columns=['crop', 'qty']
)

# %%
harvest_21
# Out:
#        crop   qty
# 0  potatoes   900
# 1    garlic  1350
# 2    onions   875

# %%
harvest_22
# Out:
#       crop   qty
# 0   garlic  1600
# 1  spinach   560
# 2  turnips   999
# 3   onions  1000

# %%
pd.concat([harvest_21, harvest_22])
# Out:
#        crop   qty
# 0  potatoes   900
# 1    garlic  1350
# 2    onions   875
# 0    garlic  1600
# 1   spinach   560
# 2   turnips   999
# 3    onions  1000

# %%
pd.concat([harvest_21, harvest_22], ignore_index=True)
# Out:
#        crop   qty
# 0  potatoes   900
# 1    garlic  1350
# 2    onions   875
# 3    garlic  1600
# 4   spinach   560
# 5   turnips   999
# 6    onions  1000

# %%
pd.concat([harvest_21, harvest_22], keys=['2021', '2022'])
# Out:
#             crop   qty
# 2021 0  potatoes   900
#      1    garlic  1350
#      2    onions   875
# 2022 0    garlic  1600
#      1   spinach   560
#      2   turnips   999
#      3    onions  1000

# %%
harvest_23 = pd.DataFrame(
    [['potatoes', 900, 500], ['garlic', 1350, 1200], ['onions', 875, 950]],
    columns=['crop', 'qty', 'profit']
)

# %%
harvest_23
# Out:
#        crop   qty  profit
# 0  potatoes   900     500
# 1    garlic  1350    1200
# 2    onions   875     950

# %%
pd.concat([harvest_21, harvest_22, harvest_23])
# Out:
#        crop   qty  profit
# 0  potatoes   900     NaN
# 1    garlic  1350     NaN
# 2    onions   875     NaN
# 0    garlic  1600     NaN
# 1   spinach   560     NaN
# 2   turnips   999     NaN
# 3    onions  1000     NaN
# 0  potatoes   900   500.0
# 1    garlic  1350  1200.0
# 2    onions   875   950.0

# %%
pd.concat([harvest_21, harvest_22, harvest_23], join='inner')
# Out:
#        crop   qty
# 0  potatoes   900
# 1    garlic  1350
# 2    onions   875
# 0    garlic  1600
# 1   spinach   560
# 2   turnips   999
# 3    onions  1000
# 0  potatoes   900
# 1    garlic  1350
# 2    onions   875

# %%
livestock = pd.DataFrame(
    [['pasture', 9], ['stable', 3], ['coop', 34]],
    columns=['location', 'qty'],
    index=['alpaca', 'horse', 'chicken']
)
weights = pd.DataFrame(
    [[4,10], [900, 2000], [1.2, 4], [110, 150]],
    columns=['min_weight', 'max_weight'],
    index=['chicken', 'horse', 'duck', 'alpaca']
)

# %%
livestock
# Out:
#         location  qty
# alpaca   pasture    9
# horse     stable    3
# chicken     coop   34

# %%
weights
# Out:
#          min_weight  max_weight
# chicken         4.0          10
# horse         900.0        2000
# duck            1.2           4
# alpaca        110.0         150

# %%
pd.concat([livestock, weights])
# Out:
#         location   qty  min_weight  max_weight
# alpaca   pasture   9.0         NaN         NaN
# horse     stable   3.0         NaN         NaN
# chicken     coop  34.0         NaN         NaN
# chicken      NaN   NaN         4.0        10.0
# horse        NaN   NaN       900.0      2000.0
# duck         NaN   NaN         1.2         4.0
# alpaca       NaN   NaN       110.0       150.0

# %%
pd.concat([livestock, weights], axis=1)
# Out:
#         location   qty  min_weight  max_weight
# alpaca   pasture   9.0       110.0         150
# horse     stable   3.0       900.0        2000
# chicken     coop  34.0         4.0          10
# duck         NaN   NaN         1.2           4

# %%
pd.concat([livestock, weights], axis=1, join='inner')
# Out:
#         location  qty  min_weight  max_weight
# alpaca   pasture    9       110.0         150
# horse     stable    3       900.0        2000
# chicken     coop   34         4.0          10

# %%
teams = pd.DataFrame(
    [
        ["Suns", "Phoenix", 20, 4],
        ["Mavericks", "Dallas", 11,12],
        ["Rockets", "Houston", 7, 16],
        ['Nuggets', "Denver", 11, 12]
    ],
    columns=["team", "city", "wins", "losses"]
)

# %%
teams
# Out:
#         team     city  wins  losses
# 0       Suns  Phoenix    20       4
# 1  Mavericks   Dallas    11      12
# 2    Rockets  Houston     7      16
# 3    Nuggets   Denver    11      12

# %%
cities = pd.DataFrame(
    [
        ["Houston", "Texas", 2310000],
        ["Phoenix", "Arizona", 1630000],
        ["San Diego", "California", 1410000],
        ["Dallas", "Texas", 1310000]
    ],
    columns=["city", "state", "population"]
)

# %%
cities
# Out:
#         city       state  population
# 0    Houston       Texas     2310000
# 1    Phoenix     Arizona     1630000
# 2  San Diego  California     1410000
# 3     Dallas       Texas     1310000

# %%
teams.merge(cities)
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
teams.merge(cities, on='city')
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
teams.merge(cities, on="city", how="inner")
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
teams.merge(cities, how="left")
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona   1630000.0
# 1  Mavericks   Dallas    11      12    Texas   1310000.0
# 2    Rockets  Houston     7      16    Texas   2310000.0
# 3    Nuggets   Denver    11      12      NaN         NaN

# %%
teams.merge(cities, how="right")
# Out:
#         team       city  wins  losses       state  population
# 0    Rockets    Houston   7.0    16.0       Texas     2310000
# 1       Suns    Phoenix  20.0     4.0     Arizona     1630000
# 2        NaN  San Diego   NaN     NaN  California     1410000
# 3  Mavericks     Dallas  11.0    12.0       Texas     1310000

# %%
teams.merge(cities, how="outer")
# Out:
#         team       city  wins  losses       state  population
# 0  Mavericks     Dallas  11.0    12.0       Texas   1310000.0
# 1    Nuggets     Denver  11.0    12.0         NaN         NaN
# 2    Rockets    Houston   7.0    16.0       Texas   2310000.0
# 3       Suns    Phoenix  20.0     4.0     Arizona   1630000.0
# 4        NaN  San Diego   NaN     NaN  California   1410000.0

# %%
teams.merge(cities, left_on="city", right_on="city")
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
teams.merge(cities, left_on="city", right_on="city", suffixes=('_team', '_city'))
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix    20       4  Arizona     1630000
# 1  Mavericks   Dallas    11      12    Texas     1310000
# 2    Rockets  Houston     7      16    Texas     2310000

# %%
cities.merge(teams, left_on="city", right_on="city")
# Out:
#       city    state  population       team  wins  losses
# 0  Houston    Texas     2310000    Rockets     7      16
# 1  Phoenix  Arizona     1630000       Suns    20       4
# 2   Dallas    Texas     1310000  Mavericks    11      12

# %%
teams.merge(cities, on="city", how="right")
# Out:
#         team       city  wins  losses       state  population
# 0    Rockets    Houston   7.0    16.0       Texas     2310000
# 1       Suns    Phoenix  20.0     4.0     Arizona     1630000
# 2        NaN  San Diego   NaN     NaN  California     1410000
# 3  Mavericks     Dallas  11.0    12.0       Texas     1310000

# %%
teams.merge(cities, on="city", how="outer")
# Out:
#         team       city  wins  losses       state  population
# 0  Mavericks     Dallas  11.0    12.0       Texas   1310000.0
# 1    Nuggets     Denver  11.0    12.0         NaN         NaN
# 2    Rockets    Houston   7.0    16.0       Texas   2310000.0
# 3       Suns    Phoenix  20.0     4.0     Arizona   1630000.0
# 4        NaN  San Diego   NaN     NaN  California   1410000.0

# %%
teams.merge(cities, on="city", how="outer", indicator=True)
# Out:
#         team       city  wins  losses       state  population      _merge
# 0  Mavericks     Dallas  11.0    12.0       Texas   1310000.0        both
# 1    Nuggets     Denver  11.0    12.0         NaN         NaN   left_only
# 2    Rockets    Houston   7.0    16.0       Texas   2310000.0        both
# 3       Suns    Phoenix  20.0     4.0     Arizona   1630000.0        both
# 4        NaN  San Diego   NaN     NaN  California   1410000.0  right_only

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "left_only"')
# Out:
#       team    city  wins  losses state  population     _merge
# 1  Nuggets  Denver  11.0    12.0   NaN         NaN  left_only

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "right_only"')
# Out:
#   team       city  wins  losses       state  population      _merge
# 4  NaN  San Diego   NaN     NaN  California   1410000.0  right_only

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "both"')
# Out:
#         team     city  wins  losses    state  population _merge
# 0  Mavericks   Dallas  11.0    12.0    Texas   1310000.0   both
# 2    Rockets  Houston   7.0    16.0    Texas   2310000.0   both
# 3       Suns  Phoenix  20.0     4.0  Arizona   1630000.0   both

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "both"').drop(columns='_merge')
# Out:
#         team     city  wins  losses    state  population
# 0  Mavericks   Dallas  11.0    12.0    Texas   1310000.0
# 2    Rockets  Houston   7.0    16.0    Texas   2310000.0
# 3       Suns  Phoenix  20.0     4.0  Arizona   1630000.0

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "both"').drop(columns='_merge').set_index('team')
# Out:
#               city  wins  losses    state  population
# team
# Mavericks   Dallas  11.0    12.0    Texas   1310000.0
# Rockets    Houston   7.0    16.0    Texas   2310000.0
# Suns       Phoenix  20.0     4.0  Arizona   1630000.0

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "both"').drop(columns='_merge').set_index('team').sort_values('city')
# Out:
#               city  wins  losses    state  population
# team
# Mavericks   Dallas  11.0    12.0    Texas   1310000.0
# Rockets    Houston   7.0    16.0    Texas   2310000.0
# Suns       Phoenix  20.0     4.0  Arizona   1630000.0

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "both"').drop(columns='_merge').set_index('team').sort_values('city', ascending=False)
# Out:
#               city  wins  losses    state  population
# team
# Suns       Phoenix  20.0     4.0  Arizona   1630000.0
# Rockets    Houston   7.0    16.0    Texas   2310000.0
# Mavericks   Dallas  11.0    12.0    Texas   1310000.0

# %%
teams.merge(cities, on="city", how="outer", indicator=True).query('_merge == "both"').drop(columns='_merge').set_index('team').sort_values('city', ascending=False).reset_index()
# Out:
#         team     city  wins  losses    state  population
# 0       Suns  Phoenix  20.0     4.0  Arizona   1630000.0
# 1    Rockets  Houston   7.0    16.0    Texas   2310000.0
# 2  Mavericks   Dallas  11.0    12.0    Texas   1310000.0

# %%
midterms = pd.DataFrame(
    [['alex', 'padilla', 92], ['rayna', 'wilson', 83], ['juan', 'gomez', 78], ['angela', 'smith', 66],['stephen', 'yu', 98]],
    columns=['first', 'last', 'score']
)

finals = pd.DataFrame(
    [['alex','padilla', 97, False], ['rayna', 'wilson', 88, False], ['alex', 'smith', 86, True], ['juan', 'gomez', 71, True], ['stephen', 'yu', 78, False], ['sakura', 'steel', 100, True]],
    columns=['first', 'last','score', 'extra_credit']
)

# %%
midterms
# Out:
#      first     last  score
# 0     alex  padilla     92
# 1    rayna   wilson     83
# 2     juan    gomez     78
# 3   angela    smith     66
# 4  stephen       yu     98

# %%
finals
# Out:
#      first     last  score  extra_credit
# 0     alex  padilla     97         False
# 1    rayna   wilson     88         False
# 2     alex    smith     86          True
# 3     juan    gomez     71          True
# 4  stephen       yu     78         False
# 5   sakura    steel    100          True

# %%
midterms.merge(finals, on="score")
# Out:
#   first_x last_x  score  first_y last_y  extra_credit
# 0    juan  gomez     78  stephen     yu         False

# %%
midterms.merge(finals, on="first")
# Out:
#      first   last_x  score_x   last_y  score_y  extra_credit
# 0     alex  padilla       92  padilla       97         False
# 1     alex  padilla       92    smith       86          True
# 2    rayna   wilson       83   wilson       88         False
# 3     juan    gomez       78    gomez       71          True
# 4  stephen       yu       98       yu       78         False

# %%
midterms.merge(finals, on=["first", "last"], how="inner")
# Out:
#      first     last  score_x  score_y  extra_credit
# 0     alex  padilla       92       97         False
# 1    rayna   wilson       83       88         False
# 2     juan    gomez       78       71          True
# 3  stephen       yu       98       78         False

# %%
midterms.merge(finals, on=["first", "last"], how="inner", suffixes=("_midterms", "_finals"))
# Out:
#      first     last  score_midterms  score_finals  extra_credit
# 0     alex  padilla              92            97         False
# 1    rayna   wilson              83            88         False
# 2     juan    gomez              78            71          True
# 3  stephen       yu              98            78         False

# %%
combo = midterms.merge(finals, on=["first", "last"], how="inner", suffixes=("_m", "_f"))

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit      avg
# 0     alex  padilla       92       97         False     094%
# 1    rayna   wilson       83       88         False     085%
# 2     juan    gomez       78       71          True     079%
# 3  stephen       yu       98       78         False     088%

# %%
combo["avg"] = (combo["score_m"] + combo["score_f"])/2

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit   avg
# 0     alex  padilla       92       97         False  94.5
# 1    rayna   wilson       83       88         False  85.5
# 2     juan    gomez       78       71          True  74.5
# 3  stephen       yu       98       78         False  88.0

# %%
combo.loc[combo["extra_credit"] == True, 'avg'] += 5

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit   avg
# 0     alex  padilla       92       97         False  94.5
# 1    rayna   wilson       83       88         False  85.5
# 2     juan    gomez       78       71          True  79.5
# 3  stephen       yu       98       78         False  88.0

# %%
combo['avg'] = combo['avg'].astype(int)

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit  avg
# 0     alex  padilla       92       97         False   94
# 1    rayna   wilson       83       88         False   85
# 2     juan    gomez       78       71          True   79
# 3  stephen       yu       98       78         False   88

# %%
combo['avg'] = combo['avg'].astype(str)

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit avg
# 0     alex  padilla       92       97         False  94
# 1    rayna   wilson       83       88         False  85
# 2     juan    gomez       78       71          True  79
# 3  stephen       yu       98       78         False  88

# %%
combo['avg'] = combo['avg'] + '%'

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit  avg
# 0     alex  padilla       92       97         False  94%
# 1    rayna   wilson       83       88         False  85%
# 2     juan    gomez       78       71          True  79%
# 3  stephen       yu       98       78         False  88%

# %%
combo['avg'] = combo['avg'].str.pad(4, side='left', fillchar='0')

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit   avg
# 0     alex  padilla       92       97         False  094%
# 1    rayna   wilson       83       88         False  085%
# 2     juan    gomez       78       71          True  079%
# 3  stephen       yu       98       78         False  088%

# %%
combo['avg'] = combo['avg'].str.pad(5, side='left', fillchar=' ')

# %%
combo
# Out:
#      first     last  score_m  score_f  extra_credit    avg
# 0     alex  padilla       92       97         False   094%
# 1    rayna   wilson       83       88         False   085%
# 2     juan    gomez       78       71          True   079%
# 3  stephen       yu       98       78         False   088%

# %%
ufos = pd.read_csv("data/nuforc_reports.csv", parse_dates=["date_time"])

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# 0        VA 2019-12-12 18:43:00      light    5 seconds
# 1        CT 2019-03-22 18:30:00     circle  3-5 seconds
# 2       NaN                 NaT        NaN          NaN
# 3        ON 2019-04-17 02:00:00   teardrop   10 seconds
# 4        NY 2009-03-15 18:00:00      cigar    2 minutes
# ...     ...                 ...        ...          ...
# 88120    AZ 2019-10-02 20:00:00  formation    3 minutes
# 88121    MO 2019-10-02 20:00:00      light   20 seconds
# 88122    FL 2019-10-02 20:03:00  formation   20 seconds
# 88123    NC 2019-10-02 22:00:00   fireball    2 minutes
# 88124    CA 2019-10-02 22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2      Occurred : 4/1/2019 15:45  (Entered as : April...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 12 columns]

# %%
ufos_19 = ufos[ufos["date_time"].dt.year == 2019]

# %%
ufos_19
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 3      I was driving towards the intersection of fall...          Ottawa
# 5      The object has flashing lights that are green,...      Kirbyville
# 6      Description is the same as Washington DC event...          Tucson
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# 0        VA 2019-12-12 18:43:00      light    5 seconds
# 1        CT 2019-03-22 18:30:00     circle  3-5 seconds
# 3        ON 2019-04-17 02:00:00   teardrop   10 seconds
# 5        TX 2019-04-02 20:25:00       disk   15 minutes
# 6        AZ 2019-05-01 11:00:00    unknown    5 minutes
# ...     ...                 ...        ...          ...
# 88120    AZ 2019-10-02 20:00:00  formation    3 minutes
# 88121    MO 2019-10-02 20:00:00      light   20 seconds
# 88122    FL 2019-10-02 20:03:00  formation   20 seconds
# 88123    NC 2019-10-02 22:00:00   fireball    2 minutes
# 88124    CA 2019-10-02 22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 5      Occurred : 4/2/2019 20:25  (Entered as : 04/02...
# 6      Occurred : 5/1/2019 11:00  (Entered as : 5/1/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 5      http://www.nuforc.org/webreports/145/S145476.html
# 6      http://www.nuforc.org/webreports/145/S145947.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 5      The object has flashing lights that are green,...  2019-04-08T00:00:00
# 6      Description is the same as Washington, DC, eve...  2019-05-09T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 3          45.381383      -75.708501
# 5          30.677200      -94.005200
# 6          32.259941     -110.927542
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [5767 rows x 12 columns]

# %%
state_pops = pd.read_csv('data/nst-est2020.csv')

# %%
state_pops = state_pops[["NAME", "POPESTIMATE2019"]]
state_pops
# Out:
#                     NAME  POPESTIMATE2019
# 0          United States        328329953
# 1       Northeast Region         56002934
# 2         Midwest Region         68340091
# 3           South Region        125686544
# 4            West Region         78300384
# 5                Alabama          4907965
# 6                 Alaska           733603
# 7                Arizona          7291843
# 8               Arkansas          3020985
# 9             California         39437610
# 10              Colorado          5758486
# 11           Connecticut          3566022
# 12              Delaware           976668
# 13  District of Columbia           708253
# 14               Florida         21492056
# 15               Georgia         10628020
# 16                Hawaii          1415615
# 17                 Idaho          1789060
# 18              Illinois         12667017
# 19               Indiana          6731010
# 20                  Iowa          3159596
# 21                Kansas          2912635
# 22              Kentucky          4472345
# 23             Louisiana          4658285
# 24                 Maine          1345770
# 25              Maryland          6054954
# 26         Massachusetts          6894883
# 27              Michigan          9984795
# 28             Minnesota          5640053
# 29           Mississippi          2978227
# 30              Missouri          6140475
# 31               Montana          1070123
# 32              Nebraska          1932571
# 33                Nevada          3090771
# 34         New Hampshire          1360783
# 35            New Jersey          8891258
# 36            New Mexico          2099634
# 37              New York         19463131
# 38        North Carolina         10501384
# 39          North Dakota           763724
# 40                  Ohio         11696507
# 41              Oklahoma          3960676
# 42                Oregon          4216116
# 43          Pennsylvania         12798883
# 44          Rhode Island          1058158
# 45        South Carolina          5157702
# 46          South Dakota           887127
# 47             Tennessee          6830325
# 48                 Texas         28986794
# 49                  Utah          3203383
# 50               Vermont           624046
# 51              Virginia          8556642
# 52            Washington          7614024
# 53         West Virginia          1795263
# 54             Wisconsin          5824581
# 55               Wyoming           580116
# 56           Puerto Rico          3193553

# %%
state_names = pd.read_csv("data/states.csv")
state_names
# Out:
#                    State  Abbrev Code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# 23             Minnesota   Minn.   MN
# 24           Mississippi   Miss.   MS
# 25              Missouri     Mo.   MO
# 26               Montana   Mont.   MT
# 27              Nebraska   Nebr.   NE
# 28                Nevada    Nev.   NV
# 29         New Hampshire    N.H.   NH
# 30            New Jersey    N.J.   NJ
# 31            New Mexico    N.M.   NM
# 32              New York    N.Y.   NY
# 33        North Carolina    N.C.   NC
# 34          North Dakota    N.D.   ND
# 35                  Ohio    Ohio   OH
# 36              Oklahoma   Okla.   OK
# 37                Oregon    Ore.   OR
# 38          Pennsylvania     Pa.   PA
# 39          Rhode Island    R.I.   RI
# 40        South Carolina    S.C.   SC
# 41          South Dakota    S.D.   SD
# 42             Tennessee   Tenn.   TN
# 43                 Texas    Tex.   TX
# 44                  Utah    Utah   UT
# 45               Vermont     Vt.   VT
# 46              Virginia     Va.   VA
# 47            Washington   Wash.   WA
# 48         West Virginia   W.Va.   WV
# 49             Wisconsin    Wis.   WI
# 50               Wyoming    Wyo.   WY

# %%
state_pops_with_code = state_pops.merge(state_names, left_on="NAME", right_on="State")

# %%
state_pops_2019 = state_pops_with_code.set_index("Code")["POPESTIMATE2019"]

# %%
state_pops_2019
# Out:
# Code
# AL     4907965
# AK      733603
# AZ     7291843
# AR     3020985
# CA    39437610
# CO     5758486
# CT     3566022
# DE      976668
# DC      708253
# FL    21492056
# GA    10628020
# HI     1415615
# ID     1789060
# IL    12667017
# IN     6731010
# IA     3159596
# KS     2912635
# KY     4472345
# LA     4658285
# ME     1345770
# MD     6054954
# MA     6894883
# MI     9984795
# MN     5640053
# MS     2978227
# MO     6140475
# MT     1070123
# NE     1932571
# NV     3090771
# NH     1360783
# NJ     8891258
# NM     2099634
# NY    19463131
# NC    10501384
# ND      763724
# OH    11696507
# OK     3960676
# OR     4216116
# PA    12798883
# RI     1058158
# SC     5157702
# SD      887127
# TN     6830325
# TX    28986794
# UT     3203383
# VT      624046
# VA     8556642
# WA     7614024
# WV     1795263
# WI     5824581
# WY      580116
# Name: POPESTIMATE2019, dtype: int64

# %%
ufos_19 = ufos_19.state.value_counts()

# %%
df = pd.concat([ufos_19, state_pops_2019], axis=1).rename({"state": "num_sightings", "POPESTIMATE2019": "population"}, axis=1)

# %%
df
# Out:
#     count  population
# CA    482  39437610.0
# FL    379  21492056.0
# TX    220  28986794.0
# AZ    217   7291843.0
# PA    214  12798883.0
# ..    ...         ...
# PR      1         NaN
# DC      1    708253.0
# NT      1         NaN
# QB      1         NaN
# YT      1         NaN
#
# [63 rows x 2 columns]

# %%
df["ufos_per_cap"] = df["count"] / df["population"]

# %%
df.sort_values("ufos_per_cap", ascending=False).head(10)
# Out:
#     count  population  ufos_per_cap
# NH     75   1360783.0      0.000055
# ID     98   1789060.0      0.000055
# MT     56   1070123.0      0.000052
# NM     83   2099634.0      0.000040
# ME     53   1345770.0      0.000039
# VT     21    624046.0      0.000034
# CT    119   3566022.0      0.000033
# HI     44   1415615.0      0.000031
# AZ    217   7291843.0      0.000030
# WA    211   7614024.0      0.000028

# %%
import matplotlib.pyplot as plt
df["ufos_per_cap"].sort_values(ascending=False).head(10).plot(kind="barh")
plt.title("UFO Sightings Per Capita")
# Out:
# Text(0.5, 1.0, 'UFO Sightings Per Capita')

# %%
d = pd.concat([ufos.state.value_counts(), state_pops_2019], axis=1)

# %%
d["cap"] = d["count"] / d['POPESTIMATE2019']

# %%
d.cap.sort_values(ascending=False).head(10).plot(kind="barh")
# Out:
# <Axes: >

# %%
ufos.state.value_counts().head(10).plot(kind="barh")
# Out:
# <Axes: ylabel='state'>
