# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.countplot(x='species', data=penguins, hue='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
penguins['species'].value_counts().plot(kind='bar', color=['red', 'green', 'blue'])
# Out:
# <Axes: xlabel='species'>

# %%
sns.countplot(x='species', data=penguins, hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
titanic = pd.read_csv('data/titanic.csv')

# %%
sns.countplot(data=titanic, x='pclass')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, x='pclass', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, y='pclass', hue='sex')
# Out:
# <Axes: xlabel='count', ylabel='pclass'>

# %%
trips = sns.load_dataset('taxis')

# %%
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.scatterplot(data=trips, x='pickup_borough', y='distance')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
sns.stripplot(data=trips, x='pickup_borough', y='distance')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
trips_sample = trips.nlargest(600, 'total')

# %%
sns.swarmplot(data=trips_sample, x='pickup_borough', y='distance')
# Out:
# C:\Users\Val\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Val\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 14.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='pickup_borough', ylabel='distance'>
# C:\Users\Val\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 19.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
plt.figure(figsize=(12, 5))
sns.swarmplot(data=trips_sample, x='pickup_borough', y='distance')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
plt.figure(figsize=(12, 5))
sns.stripplot(data=trips_sample, x='pickup_borough', y='distance')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
sns_titanic = sns.load_dataset('titanic')

# %%
sns.stripplot(data=sns_titanic, x='pclass', y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
plt.figure(figsize=(12, 5))
sns.swarmplot(data=sns_titanic, x='pclass', y='age', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=sns_titanic, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=trips, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sns.boxplot(data=sns_titanic, x='pclass', y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=sns_titanic, x='pclass', y='age', hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=penguins, x='species', y='body_mass_g')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxplot(data=penguins, x='species', y='body_mass_g')
sns.swarmplot(data=penguins, x='species', y='body_mass_g', color="0.3")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.boxenplot(data=trips, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
plt.figure(figsize=(6, 8))
sns.boxenplot(data=trips, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sns.violinplot(data=sns_titanic, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.violinplot(data=sns_titanic, x='pclass', y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.violinplot(data=sns_titanic, x='age', y='pclass')
# Out:
# <Axes: xlabel='age', ylabel='pclass'>

# %%
sns.violinplot(data=sns_titanic, x='pclass', y='age', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.violinplot(data=sns_titanic, x='pclass', y='age', hue='sex', split=True)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='distance')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='total')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='total', estimator=sum)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='total', hue='color')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='total'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='distance', hue='color')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
plt.figure(figsize=(8, 4))
sns.violinplot(data=trips, x='pickup_borough', y='distance', hue='color')
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='distance', hue='color', dodge=False)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=trips, x='pickup_borough', y='distance', hue='color', dodge=False, errorbar=None)
# Out:
# <Axes: xlabel='pickup_borough', ylabel='distance'>

# %%
sns.barplot(data=trips, y='pickup_borough', x='distance', hue='color', dodge=False)
# Out:
# <Axes: xlabel='distance', ylabel='pickup_borough'>

# %%
sns.barplot(data=sns_titanic, x='pclass', y='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
sns.barplot(data=sns_titanic, y='pclass', x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.barplot(data=sns_titanic, y='pclass', x='survived', orient='h')
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.catplot(data=sns_titanic, x='sex', y='survived', kind='bar')

# %%
sns.catplot(data=sns_titanic, x='sex', y='survived', kind='bar', col='pclass')

# %%
sns.catplot(data=sns_titanic, x='pclass', y='survived', kind='bar', hue='sex')

# %%
sns.pointplot(data=sns_titanic, x='pclass', y='survived', hue='sex')
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
sns.catplot(data=trips, kind='strip', x='pickup_borough', y='distance', col='color')

# %%
sns.catplot(data=trips, kind='violin', x='pickup_borough', y='distance', hue='color', split=True, inner='quart', gap=.1)

# %%
sns.violinplot(x=sns_titanic["age"].round(-1) + 5, y=sns_titanic["fare"], native_scale=True)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.catplot(data=trips, kind='strip', x='pickup_borough', y='distance', col='color', aspect=0.8)

# %%
sns.catplot(
    data=sns_titanic,
    kind='bar',
    x='who',
    y='survived',
    col='class'
)

# %%
sns.catplot(
    data=sns_titanic,
    kind='bar',
    x='who',
    y='survived',
    col='class',
    errorbar=None,
    row='embark_town'
)
