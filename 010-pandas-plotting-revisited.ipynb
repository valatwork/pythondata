# %% [markdown]
# ## 1. Bar plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic["age"] = pd.to_numeric(titanic["age"], errors='coerce')

# %%
houses = pd.read_csv('data/kc_house_data.csv')

# %%
ufos = pd.read_csv("data/nuforc_reports.csv", parse_dates=["date_time", "posted"])

# %%
titanic.sex.value_counts().plot(kind='bar') # this is a series with a plot method
# Out:
# <Axes: xlabel='sex'>

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10)
# Out:
#        sqft_living  sqft_lot
# 12777        13540    307752
# 7252         12050     27600
# 3914         10040     37325
# 9254          9890     31374
# 8092          9640     13068
# 4411          9200     35069
# 14556         8670     64033
# 18302         8020     21738
# 1164          8010     45517
# 1448          8000     23985

# %%
houses[["sqft_living", "sqft_lot"]].sort_values("sqft_living", ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %%
titanic.sex.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
plt.style.use('ggplot')
plt.rcdefaults()

# %%
titanic.sex.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
titanic.sex.value_counts().plot(kind='bar', title='Sex Breakdown On Titanic')
# Out:
# <Axes: title={'center': 'Sex Breakdown On Titanic'}, xlabel='sex'>

# %%
titanic.sex.value_counts().plot(kind='bar')
plt.title('My Title', loc='right')
# Out:
# Text(1.0, 1.0, 'My Title')

# %%
ufos
# Out:
#                                                                                                                                        summary  \
# 0      My wife was driving southeast on a fairly populated main side road, it was dark out side at about 6:43pm, And my wife exclaimed” fallin
# 1                                                       I think that I may caught a UFO on the NBC Nightly News that aired March 21st or 22nd.
# 2      I woke up late in the afternoon 3:30-4pm. I went to have a bath, while shaving my legs i noticed indentations around my left ankel. I t
# 3      I was driving towards the intersection of fallowfield and eagleson when I saw a where streak in the sky like a falling plane or somethi
# 4                  In Peoria Arizona, I saw a cigar shaped craft floating above the neighborhood 500 feet up silent, emitted brilliant colors,
# ...                                                                                                                                        ...
# 88120                                                                                    4 lights in formation over Tempe appear while driving
# 88121                                                                         2 bright star like lights in the NNW skys,  ((anonymous report))
# 88122                                                                           I just witnessed a ‘Phoenix Lights’ type of formation of UFOs.
# 88123  Witnessed an orange, slow moving light. Was looking out my window and saw a orange colored, non blinking light floating across the nigh
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                text  \
# 0                                                                                                                                  My wife was driving southeast on a fairly populated main side road, it was dark out side at about 6:43pm, And my wife exclaimed” falling star baby look quick!” When I looked up I saw not a falling star but a bright ball of light , one that was closer than any shooting star I have ever seen, it had a blue glow  changing into green colors of light as it fell from the sky. It fell as if falling from an invisible opening in the sky... the night was a crystal clear night sky  so no clouds or precipitation to obstruct our view and the object was closer than any I have ever witnessed before. The way the object fell was too slow to be a meteor or falling star, also noting that there was no “light trail” following behind the object as it fell. We watched it fall for about 5 seconds before it disappeared into the dark night sky somewhere close to the earth surface.  It was the strangest light; object; ufo... I have encountered and felt a duty to report it.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    I think that I may caught a UFO on the NBC Nightly News that aired March 21st or 22nd. In this short clip of a Boeing 747, as the plane flies left to right, you can see a black circular object flying eradicably (sic.  Erraticly)) behind the tail wing,  I’m guessing at a distance of about 25-30 feet. If you slow the video down you can home in on the object more so.
# 2                                                                                                                                                                       I woke up late in the afternoon 3:30-4pm.  I went to have a bath, while shaving my legs i noticed indentations around my left ankel.  I then noticed that they went all the way around the backs of both my legs and up to my thighs.  It scared me because a few nights before I was telling my fiancee that was pretty sure that i was abducted before, he laughed then that was that.  I showed him the indentations and he was shocked.  He suffers from insomnia.  We woke up at the same time.  He only sleeps maybe 4-5 hrs a wk.  He said that he slept all night with me.  The indentations look like my legs were seperated into stirups, or like how a massage chair would hold your legs.  The indents were in rows of 1-1.5 lines from my ankles all the way up to my thighs just below my buttocks.  They were perfectly lined.  They disappeared within 2 hrs of waking up.  I couldnt talk a picture because i had just lost my cell phone.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I was driving towards the intersection of fallowfield and eagleson when I saw a where streak in the sky like a falling plane or something.  I was shocked and it went down really fast towards the ground and disappeared.  Sorry for lack of details.  That is all I know.
# 4      In Peoria, Arizona, I saw a cigar shaped craft floating above the neighborhood 500 feet up silent, emitted brilliant colors, Peoria Arizona - 2009 - On my way home from work - normal evening - as I turned onto my home street i saw a huge huge craft floating above the neighborhood in front of me.  It was cigar shaped, but had a huge bulge in the middle (I used to call it a pregnant joint - if you are familiar with how that would look - skinny on the ends but bulging in the middle.  It made no noise at all and had circular shapes on the front which emitted different colored lights - like it pulsated the lights - orange to red to green to blue.  They were the most brilliant colors I’ve ever seen it’s hard to describe how perfect the colors were.  It was huge like an aircraft carrier in the sky.  It was floating and did not move at all.  I parked in my driveway and ran inside to tell my Roomate.  By the time I was outside, it was gone but there as a trail of haze.  I will never forget it. ((NUFORC Note:  Witness indicates that the date of the sighting is approximate.  PD)
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#

# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       I was driving towards the intersection of fallowfield and eagleson when I saw a where streak in the sky like a falling plane or something.  I was shocked and it went down really fast towards the ground and disappeared.  Sorry for lack of details.  That is all I know.
# 4      In Peoria, Arizona, I saw a cigar shaped craft floating above the neighborhood 500 feet up silent, emitted brilliant colors, Peoria Arizona - 2009 - On my way home from work - normal evening - as I turned onto my home street i saw a huge huge craft floating above the neighborhood in front of me.  It was cigar shaped, but had a huge bulge in the middle (I used to call it a pregnant joint - if you are familiar with how that would look - skinny on the ends but bulging in the middle.  It made no noise at all and had circular shapes on the front which emitted different colored lights - like it pulsated the lights - orange to red to green to blue.  They were the most brilliant colors I’ve ever seen it’s hard to describe how perfect the colors were.  It was huge like an aircraft carrier in the sky.  It was floating and did not move at all.  I parked in my driveway and ran inside to tell my Roomate.  By the time I was outside, it was gone but there as a trail of haze.  I will never forget it. ((NUFORC Note:  Witness indicates that the date of the sighting is approximate.  PD)
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 88120                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 4 lights in formation over Tempe appear while driving At about 8PM on Wednesday October 2nd, I was driving westbound on Elliot rd passing Dobson. I noticed a formation of 3 white lights equal distance apart.  At first it seemed as they might have been planes but they were just too close to each other.  Then I thought maybe flares,  but they didn’t seem to appear to be moving.  Approaching the 101, I noticed a 4th light appear to the left side.  As I turned northbound on the 101, I looked back to take one more look, but they seemed to be gone. . . I couldnt find them in the sky. Took video evidence of the sighting.
# 88121                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2 bright star like lights in the NNW sky two bright star like lights appeared in the sky.  I witnessed them when letting my dogs out.  They were 2 or 3 times brighter than any other star in the sky.  they were in the Northern NNW sky.  They appeared to get a little closer to each other, then they faded away.  don't know how long they were in the sky before I saw them.  It was around 8:00PM
# 88122                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      10/2/19 @ 8:03PM EST  UFO SIGHTING in the 34287, FL area:  I just witnessed a ‘Phoenix Lights’ type of formation of UFOs.  I walked out tonight because a neighbor lost something in the grass and was walking with a flashlight looking for it. I noticed something strange very high about.  I did not have a chance to video tape it due to its speed.  It was very high up, miles into the ski.  It is about dark and I noticed it coming from West and going to the East. This was huge due to the size of the formation and how high it was.  Probably 10-15 white lights in a pointed wing shape.
# 88123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Witnessed an orange, slow moving light. Was looking out my window and saw a orange colored, non blinking light floating across the night sky. Woke up my daughters to confirm what I was seeing. The object did not blink, was definitely not a helicopter. Very bright orange and moved slowly for about 2 minutes, disappeared behind the trees and did not see it again. Never seen anything like this in my life.
# 88124                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Glowing lights in formation  just south of San Quentin I witnessed 10 or 11 spherical glowing objects in formation swarming and hovering near the top of Ring Mtn. -Corte Madera.  I very quickly ran up to 2 firemen emergency responders to ask them to quote "take a quick glance at what is going on over here".  They flat out refused to take 5 steps over to the side to look at what I was trying to show them.  They were handling some kind of a medical emergency, but it would have been really nice to have them witness this because this was highlight of the whole night.
#
#           posted  city_latitude  city_longitude  month    year
# 0     2019-12-22          37.34          -77.41  12.00 2019.00
# 1     2019-03-29          41.66          -72.64   3.00 2019.00
# 2            NaT            NaN             NaN    NaN     NaN
# 3     2019-04-18          45.38          -75.71   4.00 2019.00
# 4     2019-04-18            NaN             NaN   3.00 2009.00
# ...          ...            ...             ...    ...     ...
# 88120 2019-10-04          33.41         -111.92  10.00 2019.00
# 88121 2019-10-04          37.64          -93.40  10.00 2019.00
# 88122 2019-10-04          27.08          -82.22  10.00 2019.00
# 88123 2019-10-04          35.61          -82.31  10.00 2019.00
# 88124 2019-10-04            NaN             NaN  10.00 2019.00
#
# [88125 rows x 14 columns]

# %%
ufos.month.value_counts()
# Out:
# month
# 7.00     10682
# 8.00      8997
# 9.00      8498
# 10.00     8371
# 6.00      8357
# 11.00     7596
# 12.00     6525
# 5.00      6063
# 1.00      5979
# 4.00      5817
# 3.00      5494
# 2.00      4559
# Name: count, dtype: int64

# %%
ufos.month.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind='bar',
    title='UFO Sightings By Month',
    xlabel='Month',
    ylabel='Number of Sightings',
    fontsize=10)
# Out:
# <Axes: title={'center': 'UFO Sightings By Month'}, xlabel='Month', ylabel='Number of Sightings'>

# %%
sightings.plot(
    kind='bar',
    title='UFO Sightings By Month',
    fontsize=10)
plt.xlabel('Month', fontsize=24, color='olive')
plt.ylabel('Number of Sightings', fontsize=24)
# Out:
# Text(0, 0.5, 'Number of Sightings')

# %%
sightings
# Out:
# month
# 1.00      5979
# 2.00      4559
# 3.00      5494
# 4.00      5817
# 5.00      6063
# 6.00      8357
# 7.00     10682
# 8.00      8997
# 9.00      8498
# 10.00     8371
# 11.00     7596
# 12.00     6525
# Name: count, dtype: int64

# %%
months_dict = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
sightings.rename(months_dict)
# Out:
# month
# Jan     5979
# Feb     4559
# Mar     5494
# Apr     5817
# May     6063
# Jun     8357
# Jul    10682
# Aug     8997
# Sep     8498
# Oct     8371
# Nov     7596
# Dec     6525
# Name: count, dtype: int64

# %%
sightings.rename(months_dict).plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
sightings.rename(months_dict).plot(
    kind='bar',
    title='UFO Sightings By Month',
    fontsize=20)
plt.xlabel('Month', fontsize=24, color='olive')
plt.ylabel('Number of Sightings', fontsize=24)
# Out:
# Text(0, 0.5, 'Number of Sightings')

# %%
salaries = pd.read_csv('data/salaries.csv', low_memory=False)

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"], errors='coerce').fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"], errors='coerce').fillna(0)
salaries["OtherPay"] = pd.to_numeric(salaries["OtherPay"], errors='coerce').fillna(0)

# %%
salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle   BasePay  OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY 167411.18         0.00
# 1                      CAPTAIN III (POLICE DEPARTMENT) 155966.02    245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT) 212739.13    106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  77916.00     56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT) 134401.60      9737.00
# ...                                                ...       ...          ...
# 148649                                       Custodian      0.00         0.00
# 148650                                    Not provided      0.00         0.00
# 148651                                    Not provided      0.00         0.00
# 148652                                    Not provided      0.00         0.00
# 148653                      Counselor, Log Cabin Ranch      0.00         0.00
#
#         OtherPay      Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 0      400184.25           NaN 567595.43         567595.43  2011    NaN
# 1      137811.38           NaN 538909.28         538909.28  2011    NaN
# 2       16452.60           NaN 335279.91         335279.91  2011    NaN
# 3      198306.90           NaN 332343.61         332343.61  2011    NaN
# 4      182234.59           NaN 326373.19         326373.19  2011    NaN
# ...          ...           ...       ...               ...   ...    ...
# 148649      0.00          0.00      0.00              0.00  2014    NaN
# 148650      0.00  Not Provided      0.00              0.00  2014    NaN
# 148651      0.00  Not Provided      0.00              0.00  2014    NaN
# 148652      0.00  Not Provided      0.00              0.00  2014    NaN
# 148653   -618.13          0.00   -618.13           -618.13  2014    NaN
#
#                Agency Status
# 0       San Francisco    NaN
# 1       San Francisco    NaN
# 2       San Francisco    NaN
# 3       San Francisco    NaN
# 4       San Francisco    NaN
# ...               ...    ...
# 148649  San Francisco     PT
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN
# 148653  San Francisco     PT
#
# [148654 rows x 13 columns]

# %%
df = salaries[["EmployeeName", "BasePay", "OvertimePay", "OtherPay"]]

# %%
df
# Out:
#              EmployeeName   BasePay  OvertimePay  OtherPay
# 0          NATHANIEL FORD 167411.18         0.00 400184.25
# 1            GARY JIMENEZ 155966.02    245131.88 137811.38
# 2          ALBERT PARDINI 212739.13    106088.18  16452.60
# 3       CHRISTOPHER CHONG  77916.00     56120.71 198306.90
# 4         PATRICK GARDNER 134401.60      9737.00 182234.59
# ...                   ...       ...          ...       ...
# 148649      Roy I Tillery      0.00         0.00      0.00
# 148650       Not provided      0.00         0.00      0.00
# 148651       Not provided      0.00         0.00      0.00
# 148652       Not provided      0.00         0.00      0.00
# 148653          Joe Lopez      0.00         0.00   -618.13
#
# [148654 rows x 4 columns]

# %%
df.set_index("EmployeeName", inplace=True)

# %%
df.head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df.head(10).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head()
# Out:
# EmployeeName
# Gregory P Suhr         319275.01
# Amy P Hart             318835.49
# Robert L Shaw          315572.01
# Joanne M Hayes-White   313686.01
# Harlan L Kelly-Jr      313312.52
# Name: BasePay, dtype: float64

# %%
df["BasePay"].sort_values(ascending=False).head().plot(kind='bar')
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot.bar(color='red', title="Highest Paid SF Employees")
# Out:
# <Axes: title={'center': 'Highest Paid SF Employees'}, xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot.barh(color='red', title="Highest Paid SF Employees")
# Out:
# <Axes: title={'center': 'Highest Paid SF Employees'}, ylabel='EmployeeName'>

# %%
df
# Out:
#                     BasePay  OvertimePay  OtherPay
# EmployeeName
# NATHANIEL FORD    167411.18         0.00 400184.25
# GARY JIMENEZ      155966.02    245131.88 137811.38
# ALBERT PARDINI    212739.13    106088.18  16452.60
# CHRISTOPHER CHONG  77916.00     56120.71 198306.90
# PATRICK GARDNER   134401.60      9737.00 182234.59
# ...                     ...          ...       ...
# Roy I Tillery          0.00         0.00      0.00
# Not provided           0.00         0.00      0.00
# Not provided           0.00         0.00      0.00
# Not provided           0.00         0.00      0.00
# Joe Lopez              0.00         0.00   -618.13
#
# [148654 rows x 3 columns]

# %%
df.sort_values("OvertimePay", ascending=False).head().plot(kind="barh", stacked=True)
# Out:
# <Axes: ylabel='EmployeeName'>

# %%
df.sort_values("OvertimePay", ascending=False).head().plot.barh(stacked=True)
plt.xlabel("Dollars")
# Out:
# Text(0.5, 0, 'Dollars')

# %% [markdown]
# ## 2. Histograms

# %%
df['BasePay'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['BasePay'].plot(kind='hist', bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist', bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'BasePay'}>,
#         <Axes: title={'center': 'OvertimePay'}>],
#        [<Axes: title={'center': 'OtherPay'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## 3. Line Plots

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
ufos["month"] = ufos["date_time"].dt.month
ufos["year"] = ufos["date_time"].dt.year
ufos
# Out:
#                                                                                                                                        summary  \
# 0      My wife was driving southeast on a fairly populated main side road, it was dark out side at about 6:43pm, And my wife exclaimed” fallin
# 1                                                       I think that I may caught a UFO on the NBC Nightly News that aired March 21st or 22nd.
# 2      I woke up late in the afternoon 3:30-4pm. I went to have a bath, while shaving my legs i noticed indentations around my left ankel. I t
# 3      I was driving towards the intersection of fallowfield and eagleson when I saw a where streak in the sky like a falling plane or somethi
# 4                  In Peoria Arizona, I saw a cigar shaped craft floating above the neighborhood 500 feet up silent, emitted brilliant colors,
# ...                                                                                                                                        ...
# 88120                                                                                    4 lights in formation over Tempe appear while driving
# 88121                                                                         2 bright star like lights in the NNW skys,  ((anonymous report))
# 88122                                                                           I just witnessed a ‘Phoenix Lights’ type of formation of UFOs.
# 88123  Witnessed an orange, slow moving light. Was looking out my window and saw a orange colored, non blinking light floating across the nigh
# 88124                                                                                   Glowing lights in formation  just south of San Quentin
#
#                  city state           date_time      shape     duration  \
# 0             Chester    VA 2019-12-12 18:43:00      light    5 seconds
# 1          Rocky Hill    CT 2019-03-22 18:30:00     circle  3-5 seconds
# 2                 NaN   NaN                 NaT        NaN          NaN
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      2 bright star like lights in the NNW sky two bright star like lights appeared in the sky.  I witnessed them when letting my dogs out.  They were 2 or 3 times brighter than any other star in the sky.  they were in the Northern NNW sky.  They appeared to get a little closer to each other, then they faded away.  don't know how long they were in the sky before I saw them.  It was around 8:00PM
# 88122                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      10/2/19 @ 8:03PM EST  UFO SIGHTING in the 34287, FL area:  I just witnessed a ‘Phoenix Lights’ type of formation of UFOs.  I walked out tonight because a neighbor lost something in the grass and was walking with a flashlight looking for it. I noticed something strange very high about.  I did not have a chance to video tape it due to its speed.  It was very high up, miles into the ski.  It is about dark and I noticed it coming from West and going to the East. This was huge due to the size of the formation and how high it was.  Probably 10-15 white lights in a pointed wing shape.
# 88123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Witnessed an orange, slow moving light. Was looking out my window and saw a orange colored, non blinking light floating across the night sky. Woke up my daughters to confirm what I was seeing. The object did not blink, was definitely not a helicopter. Very bright orange and moved slowly for about 2 minutes, disappeared behind the trees and did not see it again. Never seen anything like this in my life.
# 88124                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Glowing lights in formation  just south of San Quentin I witnessed 10 or 11 spherical glowing objects in formation swarming and hovering near the top of Ring Mtn. -Corte Madera.  I very quickly ran up to 2 firemen emergency responders to ask them to quote "take a quick glance at what is going on over here".  They flat out refused to take 5 steps over to the side to look at what I was trying to show them.  They were handling some kind of a medical emergency, but it would have been really nice to have them witness this because this was highlight of the whole night.
#
#           posted  city_latitude  city_longitude  month    year
# 0     2019-12-22          37.34          -77.41  12.00 2019.00
# 1     2019-03-29          41.66          -72.64   3.00 2019.00
# 2            NaT            NaN             NaN    NaN     NaN
# 3     2019-04-18          45.38          -75.71   4.00 2019.00
# 4     2019-04-18            NaN             NaN   3.00 2009.00
# ...          ...            ...             ...    ...     ...
# 88120 2019-10-04          33.41         -111.92  10.00 2019.00
# 88121 2019-10-04          37.64          -93.40  10.00 2019.00
# 88122 2019-10-04          27.08          -82.22  10.00 2019.00
# 88123 2019-10-04          35.61          -82.31  10.00 2019.00
# 88124 2019-10-04            NaN             NaN  10.00 2019.00
#
# [88125 rows x 14 columns]

# %%
plt.style.use('ggplot')
ufos.year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos.year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos.year.value_counts().sort_index().plot(kind="line", color="olive", linestyle=":")
# Out:
# <Axes: xlabel='year'>

# %%
houses.plot.line()
# Out:
# <Axes: >

# %%
houses.plot.line(y='price')
# Out:
# <Axes: >

# %%
houses.plot.line(x="bedrooms", y="price")
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# ## 4. Boxplots

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
houses.bedrooms.plot(kind='box')
# Out:
# <Axes: >

# %%
houses.bedrooms.plot(kind='box', showfliers=False)
# Out:
# <Axes: >

# %%
houses[['bedrooms', 'bathrooms']].boxplot(showfliers=False)
# Out:
# <Axes: >

# %% [markdown]
# ## 5. Scatter plots

# %%
houses.plot.scatter(x="bedrooms", y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
houses.plot.scatter(x="bedrooms", y="bathrooms", marker="X")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %% [markdown]
# ## 6. Multiple plots on the same axis

# %%
ufos[ufos["state"] == "CA"].year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["state"] == "TX"].year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["state"] == "CA"].year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"] == "TX"].year.value_counts().sort_index().plot(label="TX")
plt.title("UFO Sightings By State")
plt.legend(loc='upper left')
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# ## 7. Automatic Subplots

# %%
df.plot(kind='hist', figsize=(5,5))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist', figsize=(5,5), subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>], dtype=object)

# %%
df.plot(kind='hist', figsize=(5, 5), subplots=True)
plt.tight_layout()

# %%
df.plot(kind='hist', figsize=(5, 5), subplots=True)
plt.tight_layout(pad=3.0)

# %%
df.plot(kind='hist', figsize=(5, 5), subplots=True, sharex=False, layout=(1, 3))
plt.tight_layout()

# %%
df.plot(kind='hist', figsize=(10, 3), subplots=True, sharex=False, layout=(1, 3))
plt.tight_layout()

# %%
df.plot(kind='hist', figsize=(10, 3), subplots=True, sharex=False, layout=(1, 3), bins=30)
plt.tight_layout()

# %%
df.plot(kind='line', subplots=True, sharex=False, layout=(1, 3), figsize=(10, 3))
# Out:
# array([[<Axes: xlabel='EmployeeName'>, <Axes: xlabel='EmployeeName'>,
#         <Axes: xlabel='EmployeeName'>]], dtype=object)

# %%
df.plot(kind='line', subplots=True, sharex=False, layout=(3, 1), figsize=(10, 3))
# Out:
# array([[<Axes: xlabel='EmployeeName'>],
#        [<Axes: xlabel='EmployeeName'>],
#        [<Axes: xlabel='EmployeeName'>]], dtype=object)

# %%
axs = df.plot(kind="hist", subplots=True, sharex=False, layout=(1,3), figsize=(10,3), bins=30)
plt.tight_layout()
axs[0][2].set_xlim(0,20000)
axs[0][1].set_title("Middle")
axs[0][0].set_title("First")
axs[0][2].set_title("Third")
# Out:
# Text(0.5, 1.0, 'Third')

# %% [markdown]
# ## 8. Manual Subplots

# %%
ufos.year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos.month.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
ufos.year.value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("UFO Sightings By Year")
ufos.month.value_counts().sort_index().plot(kind='bar', ax=axs[1])
axs[1].set_title("UFO Sightings By Month")
# Out:
# Text(0.5, 1.0, 'UFO Sightings By Month')

# %%
months = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 
          7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
fig, axs = plt.subplots(2, 3, figsize=(14, 8))
fig.suptitle("UFO sightings by month", fontsize=14)
fig.tight_layout(pad=2)
ufos[ufos.year == 2014].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][0], title="2014")
ufos[ufos.year == 2015].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][1], title="2015")
ufos[ufos.year == 2016].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][2], title="2016")
ufos[ufos.year == 2017].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][0], title="2017")
ufos[ufos.year == 2018].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][1], title="2018")
ufos[ufos.year == 2019].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][2], title="2019")
plt.tight_layout()

# %% [markdown]
# ## 9. Saving plots

# %%
ufos[ufos["shape"] == "light"].year.value_counts().sort_index().plot(label="light", figsize=(10,8), title="UFO Sightings By Shape")
ufos[ufos["shape"] == "fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"] == "circle"].year.value_counts().sort_index().plot(label="circle")
ufos[ufos["shape"] == "triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"] == "formation"].year.value_counts().sort_index().plot(label="formation")

plt.xlim(2000, 2019)
plt.legend()
plt.savefig("UFO_Shapes")

# %%
months = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 
          7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
fig, axs = plt.subplots(2, 3, figsize=(14, 8))
fig.suptitle("UFO sightings by month", fontsize=14)
fig.tight_layout(pad=2)
ufos[ufos.year == 2014].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][0], title="2014")
ufos[ufos.year == 2015].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][1], title="2015")
ufos[ufos.year == 2016].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[0][2], title="2016")
ufos[ufos.year == 2017].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][0], title="2017")
ufos[ufos.year == 2018].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][1], title="2018")
ufos[ufos.year == 2019].month.value_counts().sort_index().rename(months).plot(kind="bar", ax=axs[1][2], title="2019")
plt.tight_layout()
plt.savefig("UFO_By_Month")
