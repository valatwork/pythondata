# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([2,4,6,8])

# %%
plt.plot([2,4,2,6,8,4])

# %%
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)

# %%
plt.plot(ages,salaries)
plt.show()

# %%
import numpy as np

# %%
nums = np.arange(5)
nums
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(nums,nums)

# %%
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.figure()
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.figure()
plt.plot(nums,nums*nums)
plt.figure()
plt.plot(nums,nums**3)

# %%
plt.figure(figsize=(2,6))
plt.plot(nums,nums)

# %%
plt.figure(figsize=(20,6))
plt.plot(nums,nums)

# %%
plt.figure(figsize=(2,6), dpi=200)
plt.plot(nums,nums)

# %%
plt.figure(figsize=(2,6), dpi=20)
plt.plot(nums,nums)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.style.use('seaborn-v0_8')
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.style.use('Solarize_Light2')
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.style.use('ggplot')
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.plot(nums,nums, color="olive")
plt.plot(nums,nums*nums, color="#ff6b5b")
plt.plot(nums,nums**3, c="#ff9f43")

# %%
plt.plot(nums,nums, color="olive", linewidth=4)
plt.plot(nums,nums*nums, color="#ff6b5b", linewidth=4)
plt.plot(nums,nums**3, c="#ff9f43", linewidth=4)

# %%
plt.plot(nums,nums, color="olive", linewidth=4, linestyle="dashed")
plt.plot(nums,nums*nums, color="#ff6b5b", linewidth=4, linestyle="dotted")
plt.plot(nums,nums**3, c="#ff9f43", linewidth=4, linestyle="-.")

# %%
plt.plot(nums,nums, color="olive", marker = "*", markersize=20, markerfacecolor="#ff9f43")

# %%
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.title("Company salaries")
plt.figure()
plt.plot(nums,nums, color="olive", linewidth=4, linestyle="dashed")
plt.title("Linear Stuff")
# Out:
# Text(0.5, 1.0, 'Linear Stuff')

# %%
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.title("Company salaries", fontsize=24, color="olive")
plt.xlabel("Employee Age", labelpad=20)
plt.ylabel("Average Salary", labelpad=20)
# Out:
# Text(0, 0.5, 'Average Salary')

# %%
plt.figure(figsize=(8,8))
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.title("Company salaries", fontsize=24, color="olive")
plt.xlabel("Employee Age", labelpad=20)
plt.ylabel("Average Salary", labelpad=20)
plt.xticks([20,25,30,35,40,45])
plt.yticks([60000,80000,100000,120000,140000], labels=["60k","80k","100k","120k","140k"])
# Out:
# ([<matplotlib.axis.YTick at 0x1b53b2d0b90>,
#   <matplotlib.axis.YTick at 0x1b53b548e10>,
#   <matplotlib.axis.YTick at 0x1b53b549590>,
#   <matplotlib.axis.YTick at 0x1b53b549d10>,
#   <matplotlib.axis.YTick at 0x1b53b54a490>],
#  [Text(0, 60000, '60k'),
#   Text(0, 80000, '80k'),
#   Text(0, 100000, '100k'),
#   Text(0, 120000, '120k'),
#   Text(0, 140000, '140k')])

# %%
plt.figure(figsize=(8,8))
salaries=[55000,65000,72000,90000,115000,150000]
ages=[20,25,30,32,40,45]
plt.plot(ages,salaries)
plt.xlim(25,40)
plt.ylim(80000,120000)
# Out:
# (80000.0, 120000.0)

# %%
plt.figure(figsize=(8,8))
plt.plot(nums, color="teal", label="x")
plt.plot(nums*nums, color="olive", label="x squared")
plt.plot(nums**3, color="purple", label="x cubed")
plt.legend()

# %%
plt.figure(figsize=(8,8))
plt.plot(nums, color="teal", label="x")
plt.plot(nums*nums, color="olive", label="x squared")
plt.plot(nums**3, color="purple", label="x cubed")
plt.legend(loc="center left", frameon=True, shadow=True, facecolor="white")
