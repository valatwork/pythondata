# %%
import pandas as pd

# %%
titanic = pd.read_csv('./data/titanic.csv')
titanic['age'] = titanic['age'].replace(['?'], [None]).astype(float)
titanic['fare'] = titanic['fare'].replace(['?'], [None]).astype(float)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest
# 0       ?                     St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON
# 2       ?  Montreal, PQ / Chesterville, ON
# 3     135  Montreal, PQ / Chesterville, ON
# 4       ?  Montreal, PQ / Chesterville, ON
# ...   ...                              ...
# 1304  328                                ?
# 1305    ?                                ?
# 1306  304                                ?
# 1307    ?                                ?
# 1308    ?                                ?
#
# [1309 rows x 14 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 143.3+ KB

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"].str.split(", ")
# Out:
# 0                         [Allen, Miss. Elisabeth Walton]
# 1                        [Allison, Master. Hudson Trevor]
# 2                          [Allison, Miss. Helen Loraine]
# 3                  [Allison, Mr. Hudson Joshua Creighton]
# 4       [Allison, Mrs. Hudson J C (Bessie Waldo Daniels)]
#                               ...
# 1304                               [Zabour, Miss. Hileni]
# 1305                              [Zabour, Miss. Thamine]
# 1306                          [Zakarian, Mr. Mapriededer]
# 1307                                [Zakarian, Mr. Ortin]
# 1308                                 [Zimmerman, Mr. Leo]
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"].str.split(", ", expand=True)
# Out:
#               0                                       1
# 0         Allen                  Miss. Elisabeth Walton
# 1       Allison                   Master. Hudson Trevor
# 2       Allison                     Miss. Helen Loraine
# 3       Allison             Mr. Hudson Joshua Creighton
# 4       Allison  Mrs. Hudson J C (Bessie Waldo Daniels)
# ...         ...                                     ...
# 1304     Zabour                            Miss. Hileni
# 1305     Zabour                           Miss. Thamine
# 1306   Zakarian                         Mr. Mapriededer
# 1307   Zakarian                               Mr. Ortin
# 1308  Zimmerman                                 Mr. Leo
#
# [1309 rows x 2 columns]

# %%
titanic["name"].str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"].str.lower()
# Out:
# 0                         allen, miss. elisabeth walton
# 1                        allison, master. hudson trevor
# 2                          allison, miss. helen loraine
# 3                  allison, mr. hudson joshua creighton
# 4       allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               zabour, miss. hileni
# 1305                              zabour, miss. thamine
# 1306                          zakarian, mr. mapriededer
# 1307                                zakarian, mr. ortin
# 1308                                 zimmerman, mr. leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["cabin"].str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic["deck"] = titanic["cabin"].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest deck
# 0       ?                     St Louis, MO    B
# 1       ?  Montreal, PQ / Chesterville, ON    C
# 2       ?  Montreal, PQ / Chesterville, ON    C
# 3     135  Montreal, PQ / Chesterville, ON    C
# 4       ?  Montreal, PQ / Chesterville, ON    C
# ...   ...                              ...  ...
# 1304  328                                ?    ?
# 1305    ?                                ?    ?
# 1306  304                                ?    ?
# 1307    ?                                ?    ?
# 1308    ?                                ?    ?
#
# [1309 rows x 15 columns]

# %%
titanic.groupby("deck").mean(numeric_only=True)
# Out:
#         pclass  survived        age     sibsp     parch        fare
# deck
# ?     2.617357  0.302761  27.406654  0.503945  0.367850   19.132707
# A     1.000000  0.500000  44.157895  0.181818  0.181818   41.244314
# B     1.000000  0.723077  36.476190  0.446154  0.661538  122.383078
# C     1.000000  0.606383  38.382752  0.680851  0.414894  107.926598
# D     1.130435  0.695652  39.702381  0.413043  0.260870   53.007339
# E     1.243902  0.731707  38.118421  0.341463  0.390244   54.564634
# F     2.380952  0.619048  21.333333  0.428571  0.523810   18.079367
# G     3.000000  0.600000  12.000000  0.600000  1.200000   14.205000
# T     1.000000  0.000000  45.000000  0.000000  0.000000   35.500000

# %%
titanic
titanic.groupby("deck")["survived"].mean(numeric_only=True).sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='deck'>

# %%
titanic.cabin
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304          ?
# 1305          ?
# 1306          ?
# 1307          ?
# 1308          ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic.cabin.str[1:]
# Out:
# 0            5
# 1       22 C26
# 2       22 C26
# 3       22 C26
# 4       22 C26
#          ...
# 1304
# 1305
# 1306
# 1307
# 1308
# Name: cabin, Length: 1309, dtype: object

# %%
s = pd.Series(['1. Hawk. ', '2. Pickle!\n', '3. Melonhead?\t'])

# %%
s
# Out:
# 0          1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip("1.")
# Out:
# 0             Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip("123. ")
# Out:
# 0            Hawk
# 1       Pickle!\n
# 2    Melonhead?\t
# dtype: object

# %%
s.str.strip("123. \n\t")
# Out:
# 0          Hawk
# 1       Pickle!
# 2    Melonhead?
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.lstrip()
# Out:
# 0          1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest deck
# 0       ?                     St Louis, MO    B
# 1       ?  Montreal, PQ / Chesterville, ON    C
# 2       ?  Montreal, PQ / Chesterville, ON    C
# 3     135  Montreal, PQ / Chesterville, ON    C
# 4       ?  Montreal, PQ / Chesterville, ON    C
# ...   ...                              ...  ...
# 1304  328                                ?    ?
# 1305    ?                                ?    ?
# 1306  304                                ?    ?
# 1307    ?                                ?    ?
# 1308    ?                                ?    ?
#
# [1309 rows x 15 columns]

# %%
titanic["home.dest"].str.split("/")
# Out:
# 0                           [St Louis, MO]
# 1       [Montreal, PQ ,  Chesterville, ON]
# 2       [Montreal, PQ ,  Chesterville, ON]
# 3       [Montreal, PQ ,  Chesterville, ON]
# 4       [Montreal, PQ ,  Chesterville, ON]
#                        ...
# 1304                                   [?]
# 1305                                   [?]
# 1306                                   [?]
# 1307                                   [?]
# 1308                                   [?]
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic["home.dest"].str.split("/")[1]
# Out:
# ['Montreal, PQ ', ' Chesterville, ON']

# %%
titanic["home.dest"].str.split("/", expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic["home"] = titanic["home.dest"].str.split("/", expand=True)[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest deck           home
# 0       ?                     St Louis, MO    B   St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# 2       ?  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# 3     135  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# 4       ?  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# ...   ...                              ...  ...            ...
# 1304  328                                ?    ?              ?
# 1305    ?                                ?    ?              ?
# 1306  304                                ?    ?              ?
# 1307    ?                                ?    ?              ?
# 1308    ?                                ?    ?              ?
#
# [1309 rows x 16 columns]

# %%
titanic["destination"] = titanic["home.dest"].str.split("/", expand=True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S    ?
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S    ?
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S    ?
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542        ?        C    ?
# 1305  female      NaN      1      0    2665   14.4542        ?        C    ?
# 1306    male  26.5000      0      0    2656    7.2250        ?        C    ?
# 1307    male  27.0000      0      0    2670    7.2250        ?        C    ?
# 1308    male  29.0000      0      0  315082    7.8750        ?        S    ?
#
#      body                        home.dest deck           home  \
# 0       ?                     St Louis, MO    B   St Louis, MO
# 1       ?  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# 2       ?  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# 3     135  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# 4       ?  Montreal, PQ / Chesterville, ON    C  Montreal, PQ
# ...   ...                              ...  ...            ...
# 1304  328                                ?    ?              ?
# 1305    ?                                ?    ?              ?
# 1306  304                                ?    ?              ?
# 1307    ?                                ?    ?              ?
# 1308    ?                                ?    ?              ?
#
#             destination
# 0                  None
# 1      Chesterville, ON
# 2      Chesterville, ON
# 3      Chesterville, ON
# 4      Chesterville, ON
# ...                 ...
# 1304               None
# 1305               None
# 1306               None
# 1307               None
# 1308               None
#
# [1309 rows x 17 columns]

# %%
titanic["home"].value_counts()
# Out:
# home
# ?                                 564
# New York, NY                       64
# Cornwall                           19
# London                             14
# London                             13
#                                  ...
# Stoughton, MA                       1
# Liverpool, England                  1
# Antwerp, Belgium                    1
# St Denys, Southampton, Hants        1
# Co Sligo, Ireland Hartford, CT      1
# Name: count, Length: 339, dtype: int64

# %%
titanic["destination"].value_counts()
# Out:
# destination
# Akron, OH            11
# Montreal, PQ          9
# New York, NY          9
# Detroit, MI           6
# Cooperstown, NY       5
#                      ..
# Minneapolis, MN       1
# Hartford, CT          1
# Edgewood, RI          1
# Cottage Grove, OR     1
# Stanton, OH           1
# Name: count, Length: 77, dtype: int64

# %%
ufos = pd.read_csv('./data/nuforc_reports.csv')

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# 0        VA  2019-12-12T18:43:00      light    5 seconds
# 1        CT  2019-03-22T18:30:00     circle  3-5 seconds
# 2       NaN                  NaN        NaN          NaN
# 3        ON  2019-04-17T02:00:00   teardrop   10 seconds
# 4        NY  2009-03-15T18:00:00      cigar    2 minutes
# ...     ...                  ...        ...          ...
# 88120    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121    MO  2019-10-02T20:00:00      light   20 seconds
# 88122    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2      Occurred : 4/1/2019 15:45  (Entered as : April...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 12 columns]

# %%
ufos["duration"]
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds", "s")
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo):
    print(reo)
    return "HI"

# %%
ufos["duration"].str.replace("seconds|minutes|hours", abbrv, regex=True)
# Out:
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(0, 7), match='minutes'>
# <re.Match object; span=(0, 5), match='hours'>
# <re.Match object; span=(15, 20), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 8), match='hours'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(9, 16), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(8, 15), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(11, 16), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(8, 15), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(8, 15), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(8, 15), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(1, 8), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(10, 17), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(9, 16), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(8, 15), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(9, 16), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(0, 7), match='seconds'>
# <re.Match object; span=(1, 8), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(1, 6), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(9, 16), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(11, 18), match='minutes'>
# <re.Match object; span=(7, 14), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(10, 17), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(1, 8), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(9, 16), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(0, 5), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(1, 8), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(1, 8), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(8, 15), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(0, 7), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(9, 16), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(0, 7), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(10, 17), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(16, 23), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 8), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(13, 20), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(7, 14), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(13, 20), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(7, 14), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(7, 14), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(7, 14), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(9, 16), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(9, 16), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 8), match='hours'>
# <re.Match object; span=(3, 8), match='hours'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(1, 6), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 11), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(8, 15), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 11), match='hours'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(7, 14), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(10, 17), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(0, 5), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(0, 7), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(0, 7), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(7, 14), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(13, 20), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(12, 19), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(0, 5), match='hours'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(7, 14), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# ...
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(12, 19), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(6, 13), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 7), match='hours'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(5, 12), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(5, 12), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 9), match='hours'>
# <re.Match object; span=(5, 10), match='hours'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# 0          5 HI
# 1        3-5 HI
# 2           NaN
# 3         10 HI
# 4          2 HI
#           ...
# 88120      3 HI
# 88121     20 HI
# 88122     20 HI
# 88123      2 HI
# 88124      3 HI
# Name: duration, Length: 88125, dtype: object

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# 0        VA  2019-12-12T18:43:00      light    5 seconds
# 1        CT  2019-03-22T18:30:00     circle  3-5 seconds
# 2       NaN                  NaN        NaN          NaN
# 3        ON  2019-04-17T02:00:00   teardrop   10 seconds
# 4        NY  2009-03-15T18:00:00      cigar    2 minutes
# ...     ...                  ...        ...          ...
# 88120    AZ  2019-10-02T20:00:00  formation    3 minutes
# 88121    MO  2019-10-02T20:00:00      light   20 seconds
# 88122    FL  2019-10-02T20:03:00  formation   20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball    2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere    3 minutes
#
#                                                    stats  \
# 0      Occurred : 12/12/2019 18:43  (Entered as : 12/...
# 1      Occurred : 3/22/2019 18:30  (Entered as : 03/2...
# 2      Occurred : 4/1/2019 15:45  (Entered as : April...
# 3      Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 4      Occurred : 3/15/2009 18:00  (Entered as : 03/1...
# ...                                                  ...
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# 88122  Occurred : 10/2/2019 20:03  (Entered as : 10/0...
# 88123  Occurred : 10/2/2019 22:00  (Entered as : 10/0...
# 88124  Occurred : 10/2/2019 22:00  (Entered as : 10-0...
#
#                                              report_link  \
# 0      http://www.nuforc.org/webreports/151/S151739.html
# 1      http://www.nuforc.org/webreports/145/S145297.html
# 2      http://www.nuforc.org/webreports/145/S145556.html
# 3      http://www.nuforc.org/webreports/145/S145697.html
# 4      http://www.nuforc.org/webreports/145/S145723.html
# ...                                                  ...
# 88120  http://www.nuforc.org/webreports/149/S149463.html
# 88121  http://www.nuforc.org/webreports/149/S149405.html
# 88122  http://www.nuforc.org/webreports/149/S149424.html
# 88123  http://www.nuforc.org/webreports/149/S149447.html
# 88124  http://www.nuforc.org/webreports/149/S149436.html
#
#                                                     text               posted  \
# 0      My wife was driving southeast on a fairly popu...  2019-12-22T00:00:00
# 1      I think that I may caught a UFO on the NBC Nig...  2019-03-29T00:00:00
# 2      I woke up late in the afternoon 3:30-4pm.  I w...                  NaN
# 3      I was driving towards the intersection of fall...  2019-04-18T00:00:00
# 4      In Peoria, Arizona, I saw a cigar shaped craft...  2019-04-18T00:00:00
# ...                                                  ...                  ...
# 88120  4 lights in formation over Tempe appear while ...  2019-10-04T00:00:00
# 88121  2 bright star like lights in the NNW sky two b...  2019-10-04T00:00:00
# 88122  10/2/19 @ 8:03PM EST  UFO SIGHTING in the 3428...  2019-10-04T00:00:00
# 88123  Witnessed an orange, slow moving light. Was lo...  2019-10-04T00:00:00
# 88124  Glowing lights in formation  just south of San...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 0          37.343152      -77.408582
# 1          41.664800      -72.639300
# 2                NaN             NaN
# 3          45.381383      -75.708501
# 4                NaN             NaN
# ...              ...             ...
# 88120      33.414036     -111.920920
# 88121      37.642200      -93.399600
# 88122      27.076210      -82.223280
# 88123      35.605000      -82.313200
# 88124            NaN             NaN
#
# [88125 rows x 12 columns]

# %%
def abbrv(reo):
    return reo.group(0)[0]

# %%
ufos["duration"].str.replace("seconds|minutes|hours", abbrv, regex=True)
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.contains("5")
# Out:
# 0         True
# 1         True
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.contains("hour")
# Out:
# 0        False
# 1        False
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos[ufos["duration"].str.contains("hour", na=False)]
# Out:
#                                                  summary             city  \
# 10     Metal orb of wires that was seen through a tel...       Brookville
# 14     Bright Circle of Light followed me from Oskalo...      Centerville
# 36     Looked like airplanes without windows,  wings,...        Morehouse
# 37     01/20/51     Palm Springs CA     light     hou...     Palm Springs
# 40     5/16/1958/ 1500 hours/ just getting dark,mount...       Cincinnati
# ...                                                  ...              ...
# 88013  Unidentified flying object seen multiple night...  New port richey
# 88018  On balcony enjoying a beautiful night by the b...         New York
# 88064  Unidentified object moving very slowly across ...    Pt. St. Lucie
# 88065              White circular object above Ft Pierce      Fort Pierce
# 88073                                Lights in Texas sky           Slocum
#
#       state            date_time     shape              duration  \
# 10       IN  2019-06-18T21:00:00    sphere                1 hour
# 14       IA  1999-08-15T02:30:00    circle                1 hour
# 36       MO                  NaN  cylinder                 hours
# 37       CA                  NaN     cigar  one and a half hours
# 40       OH                  NaN   diamond              24 hours
# ...     ...                  ...       ...                   ...
# 88013    FL  2019-09-27T21:00:00   unknown                1 hour
# 88018    NY  2019-09-27T22:00:00     light                1 hour
# 88064    FL  2019-09-29T17:00:00    circle             1.5 hours
# 88065    FL  2019-09-29T17:20:00    circle            1:30 hours
# 88073    TX  2019-09-29T23:00:00     light               >1 hour
#
#                                                    stats  \
# 10     Occurred : 6/18/2019 21:00  (Entered as : 6/18...
# 14     Occurred : 8/15/1999 02:30  (Entered as : 08/1...
# 36     Occurred : 7/15/1947 21:00  (Entered as : 07/?...
# 37     Occurred : 1/20/1951 04:30  (Entered as : 01/2...
# 40     Occurred : 5/16/1958   (Entered as : 05/16/58)...
# ...                                                  ...
# 88013  Occurred : 9/27/2019 21:00  (Entered as : 09/2...
# 88018  Occurred : 9/27/2019 22:00  (Entered as : 09/2...
# 88064  Occurred : 9/29/2019 17:00  (Entered as : 09/2...
# 88065  Occurred : 9/29/2019 17:20  (Entered as : 9/29...
# 88073  Occurred : 9/29/2019 23:00  (Entered as : 09/2...
#
#                                              report_link  \
# 10     http://www.nuforc.org/webreports/146/S146900.html
# 14     http://www.nuforc.org/webreports/146/S146702.html
# 36      http://www.nuforc.org/webreports/049/S49557.html
# 37      http://www.nuforc.org/webreports/050/S50060.html
# 40      http://www.nuforc.org/webreports/049/S49850.html
# ...                                                  ...
# 88013  http://www.nuforc.org/webreports/149/S149318.html
# 88018  http://www.nuforc.org/webreports/149/S149283.html
# 88064  http://www.nuforc.org/webreports/149/S149338.html
# 88065  http://www.nuforc.org/webreports/149/S149345.html
# 88073  http://www.nuforc.org/webreports/149/S149344.html
#
#                                                     text               posted  \
# 10     Metal orb of wires that was seen through a tel...  2019-06-20T00:00:00
# 14     Bright Circle of Light followed me from Oskalo...  2019-06-20T00:00:00
# 36     Looked like airplanes without windows, wings, ...                  NaN
# 37     01/20/51     Palm Springs CA     light     hou...                  NaN
# 40     5/16/1958/ 1500 hours/ just getting dark,mount...                  NaN
# ...                                                  ...                  ...
# 88013  Unidentified flying object seen multiple night...  2019-10-04T00:00:00
# 88018  On balcony enjoying a beautiful night by the b...  2019-10-04T00:00:00
# 88064  Unidentified object moving very slowly across ...  2019-10-04T00:00:00
# 88065  White circular object above Ft Pierce Very lar...  2019-10-04T00:00:00
# 88073  Lights in Texas sky Saw a strange bright light...  2019-10-04T00:00:00
#
#        city_latitude  city_longitude
# 10         39.404700      -84.973600
# 14         40.707400      -92.921300
# 36         36.849900      -89.677200
# 37         33.800165     -116.535373
# 40         39.174503      -84.481363
# ...              ...             ...
# 88013      28.242700      -82.677239
# 88018      40.744307      -73.987724
# 88064            NaN             NaN
# 88065            NaN             NaN
# 88073            NaN             NaN
#
# [4656 rows x 12 columns]

# %%
ufos[ufos["duration"].str.contains("day|week|month", na=False)]
# Out:
#                                                  summary  \
# 107    7 large yellow lights with red center  estimat...
# 116    Saw one large ship during the day around noon ...
# 286    film makers in hollywood where talking of film...
# 290                               End of the Century UFO
# 1355   A white ball of light made several appearances...
# ...                                                  ...
# 84021  The Beings and Craft of Taos County.  ((NUFORC...
# 84983  In 1967 I am a little kid now. I am sleeping I...
# 85717  There was a big bright colored triangle object...
# 86210  2 flying diamonds; red and gold lights; creaki...
# 87707  Lights seen from the night sky 1st night-flick...
#
#                           city state            date_time      shape  \
# 107                    Griffin    GA  1984-03-15T20:00:00     circle
# 116                  Knoxville    TN  1986-04-04T23:00:00  rectangle
# 286                    Arizona    AZ  1997-07-07T00:00:00   triangle
# 290    Cebu City (Philippines)   NaN  1998-03-01T20:00:00      other
# 1355                     Genoa    IL  2007-01-25T22:00:00     sphere
# ...                        ...   ...                  ...        ...
# 84021                     Taos    NM  2019-09-01T10:00:00      other
# 84983                   Saugas    CA                  NaN        NaN
# 85717                  Houston    BC  2019-11-25T03:30:00   triangle
# 86210                   Dallas    TX  2019-10-11T01:44:00    diamond
# 87707                    Haiku    HI  2019-11-25T00:00:00      light
#
#             duration                                              stats  \
# 107         3 months  Occurred : 3/15/1984 20:00  (Entered as : marc...
# 116             week  Occurred : 4/4/1986 23:00  (Entered as : 03150...
# 286       all months  Occurred : 7/7/1997   (Entered as : 7 7 1997) ...
# 290    1 to 2 months  Occurred : 3/1/1998 20:00  (Entered as : 03/01...
# 1355        5 months  Occurred : 1/25/2007 22:00  (Entered as : 01/2...
# ...              ...                                                ...
# 84021         2 days  Occurred : 9/1/2019 10:00  (Entered as : 09/01...
# 84983         3 days  Occurred : 6/30/1967 04:00 Reported: 12/19/201...
# 85717  Till daylight  Occurred : 11/25/2019 03:30  (Entered as : 11/...
# 86210         2 days  Occurred : 10/11/2019 01:44  (Entered as : 10/...
# 87707         4 days  Occurred : 11/25/2019  Reported: 11/29/2019 7:...
#
#                                              report_link  \
# 107     http://www.nuforc.org/webreports/050/S50375.html
# 116     http://www.nuforc.org/webreports/049/S49786.html
# 286     http://www.nuforc.org/webreports/049/S49553.html
# 290     http://www.nuforc.org/webreports/050/S50203.html
# 1355   http://www.nuforc.org/webreports/146/S146567.html
# ...                                                  ...
# 84021  http://www.nuforc.org/webreports/148/S148913.html
# 84983  http://www.nuforc.org/webreports/144/S144137.html
# 85717  http://www.nuforc.org/webreports/151/S151095.html
# 86210  http://www.nuforc.org/webreports/150/S150378.html
# 87707  http://www.nuforc.org/webreports/151/S151166.html
#
#                                                     text               posted  \
# 107    7 large yellow lights with red center  estimat...  2006-05-15T00:00:00
# 116    Saw one large ship during the day around noon ...  2006-05-15T00:00:00
# 286    film makers in hollywood where talking of film...  2006-05-15T00:00:00
# 290    End of the Century UFO First of all I'd like t...  2006-05-15T00:00:00
# 1355   A white ball of light made several appearances...  2019-06-07T00:00:00
# ...                                                  ...                  ...
# 84021  The Beings and Craft of Taos County. ((NUFORC ...  2019-09-19T00:00:00
# 84983  In 1967 I am a little kid now.  I am sleeping ...                  NaN
# 85717  There was a big bright colored triangle object...  2019-12-01T00:00:00
# 86210  2 flying diamonds; red and gold lights; creaki...  2019-12-01T00:00:00
# 87707  Lights seen from the night sky 1st night-flick...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 107        33.248869      -84.249217
# 116        35.961561      -83.980115
# 286              NaN             NaN
# 290              NaN             NaN
# 1355       42.108600      -88.686000
# ...              ...             ...
# 84021      36.414600     -105.522200
# 84983            NaN             NaN
# 85717      54.400000     -126.650000
# 86210      32.835168      -96.808118
# 87707      20.858800     -156.140500
#
# [204 rows x 12 columns]
